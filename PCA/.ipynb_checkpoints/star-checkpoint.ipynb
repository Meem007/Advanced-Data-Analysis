# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ss-computer\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ss-computer\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ss-computer\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ss-computer\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\ss-computer\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd
df=pd.read_csv('stars.csv') 
df.head(5)
# Out:
#    Temperature         L       R    A_M Color Spectral_Class  Type
# 0         3068  0.002400  0.1700  16.12   Red              M     0
# 1         3042  0.000500  0.1542  16.60   Red              M     0
# 2         2600  0.000300  0.1020  18.70   Red              M     0
# 3         2800  0.000200  0.1600  16.65   Red              M     0
# 4         1939  0.000138  0.1030  20.06   Red              M     0

# %%
# from 
# 0 to 5
# Red Dwarf - 0
# Brown Dwarf - 1
# White Dwarf - 2
# Main Sequence - 3
# Super Giants - 4
# Hyper Giants - 5

# %%
from sklearn.preprocessing import StandardScaler

features = ['Temperature', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides','free sulfur dioxide',
            'total sulfur dioxide','density','pH','sulphates','alcohol' ]
# Separating out the features
x = df.loc[:, features].values
# Separating out the target
y = df.loc[:,['quality']].values
# Standardizing the features
x = StandardScaler().fit_transform(x)
x
# Out:
# array([[-0.52835961,  0.96187667, -1.39147228, ...,  1.28864292,
#         -0.57920652, -0.96024611],
#        [-0.29854743,  1.96744245, -1.39147228, ..., -0.7199333 ,
#          0.1289504 , -0.58477711],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.33117661,
#         -0.04808883, -0.58477711],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.70550789,
#          0.54204194,  0.54162988],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  1.6773996 ,
#          0.30598963, -0.20930812],
#        [-1.33270223, -1.21684919,  1.02199944, ...,  0.51112954,
#          0.01092425,  0.54162988]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['PC 1', 'PC 2', 'PC 3'])
principalDf
# Out:
#           PC 1      PC 2      PC 3
# 0    -1.619530  0.450950 -1.774454
# 1    -0.799170  1.856553 -0.911690
# 2    -0.748479  0.882039 -1.171394
# 3     2.357673 -0.269976  0.243489
# 4    -1.619530  0.450950 -1.774454
# ...        ...       ...       ...
# 1594 -2.150500  0.814286  0.617063
# 1595 -2.214496  0.893101  1.807402
# 1596 -1.456129  0.311746  1.124239
# 1597 -2.270518  0.979791  0.627965
# 1598 -0.426975 -0.536690  1.628955
#
# [1599 rows x 3 columns]

# %%
finalDf = pd.concat([principalDf, df[['quality']]], axis = 1)
finalDf
# Out:
#           PC 1      PC 2      PC 3  quality
# 0    -1.619530  0.450950 -1.774454        5
# 1    -0.799170  1.856553 -0.911690        5
# 2    -0.748479  0.882039 -1.171394        5
# 3     2.357673 -0.269976  0.243489        6
# 4    -1.619530  0.450950 -1.774454        5
# ...        ...       ...       ...      ...
# 1594 -2.150500  0.814286  0.617063        5
# 1595 -2.214496  0.893101  1.807402        6
# 1596 -1.456129  0.311746  1.124239        6
# 1597 -2.270518  0.979791  0.627965        5
# 1598 -0.426975 -0.536690  1.628955        6
#
# [1599 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('PC 1', fontsize = 15)
ax.set_ylabel('PC 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [5, 6, 8]
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['quality'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'PC 1']
               , finalDf.loc[indicesToKeep, 'PC 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.28173931, 0.1750827 , 0.1409585 ])
